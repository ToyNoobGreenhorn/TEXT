# %%
cd /home/ubuntu/pynb/bbc3
# Out:
# /home/ubuntu/pynb/bbc3

# %%
pwd
# Out:
# u'/home/ubuntu/pynb/bbc3'

# %%
import pickle
heads = []
descs = []
keywords = []
for filenames in range(1):

    with open('301.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('302.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('303.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('304.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('305.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('306.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('307.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('308.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('309.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('310.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('311.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('312.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('313.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('314.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('315.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('316.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('317.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('318.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('319.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('320.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('321.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('322.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('323.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('324.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('325.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('326.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('327.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('328.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('329.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('330.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('331.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('332.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('333.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('334.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('335.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('336.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('337.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('338.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('339.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('340.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('341.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('342.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('343.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('344.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('345.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('346.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('347.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('348.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('349.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('350.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('351.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('352.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('353.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('354.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('355.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('356.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('357.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('358.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('359.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('360.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('361.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('362.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('363.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('364.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('365.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('366.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('367.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('368.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('369.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('370.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('371.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('372.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('373.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('374.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('375.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('376.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('377.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('378.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('379.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('380.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('381.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('382.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('383.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('384.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('385.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('386.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('387.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('388.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('389.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('390.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('391.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('392.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('393.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('394.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('395.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('396.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('397.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('398.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('399.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
 
    with open('400.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)        
 
    with open('401.txt', 'r') as fp:
        text = fp.read()
        temp = text
        heads.append(temp.split("\n")[0])
        descs.append(text) 
        keywords.append(None)
                 
        
        print(heads,descs,keywords)
# Out:
# (['Rivals of the \xc2\xa3400 Apple...', 'Speak easy plan for media players', 'US peer-to-peer pirates convicted', "Format wars could 'confuse users'", 'Mobiles get set for visual radio', 'Gamers could drive high-definition', 'How to make a greener computer', 'Microsoft makes anti-piracy move', "What's next for next-gen consoles?", 'Latest Opera browser gets vocal', 'Mobile games come of age', 'Web radio takes Spanish rap global', 'What high-definition will do to DVDs', 'Junk e-mails on relentless rise', 'Warning over tsunami aid website', 'More women turn to net security', 'Sony PSP console hits US in March', 'Ask Jeeves joins web log market', 'Why Cell will get the hard sell', 'PlayStation 3 processor unveiled', 'Consumer concern over RFID tags', "Mobiles 'not media players yet'", "Blind student 'hears in colour'", 'Apple attacked over sources row', 'Mobile audio enters new dimension', 'DVD copy protection strengthened', 'Millions buy MP3 players in US', 'Britons fed up with net ser
# ...

# %%
with open('fourrea.pkl', 'wb') as f:
     pickle.dump((heads,descs,keywords),f)
     print(heads,descs,keywords)
# Out:
# (['Rivals of the \xc2\xa3400 Apple...', 'Speak easy plan for media players', 'US peer-to-peer pirates convicted', "Format wars could 'confuse users'", 'Mobiles get set for visual radio', 'Gamers could drive high-definition', 'How to make a greener computer', 'Microsoft makes anti-piracy move', "What's next for next-gen consoles?", 'Latest Opera browser gets vocal', 'Mobile games come of age', 'Web radio takes Spanish rap global', 'What high-definition will do to DVDs', 'Junk e-mails on relentless rise', 'Warning over tsunami aid website', 'More women turn to net security', 'Sony PSP console hits US in March', 'Ask Jeeves joins web log market', 'Why Cell will get the hard sell', 'PlayStation 3 processor unveiled', 'Consumer concern over RFID tags', "Mobiles 'not media players yet'", "Blind student 'hears in colour'", 'Apple attacked over sources row', 'Mobile audio enters new dimension', 'DVD copy protection strengthened', 'Millions buy MP3 players in US', 'Britons fed up with net ser
# ...

# %%
pickle_off = open("fourrea.pkl","rb")
emp = pickle.load(pickle_off)
print(emp)
# Out:
# (['Rivals of the \xc2\xa3400 Apple...', 'Speak easy plan for media players', 'US peer-to-peer pirates convicted', "Format wars could 'confuse users'", 'Mobiles get set for visual radio', 'Gamers could drive high-definition', 'How to make a greener computer', 'Microsoft makes anti-piracy move', "What's next for next-gen consoles?", 'Latest Opera browser gets vocal', 'Mobile games come of age', 'Web radio takes Spanish rap global', 'What high-definition will do to DVDs', 'Junk e-mails on relentless rise', 'Warning over tsunami aid website', 'More women turn to net security', 'Sony PSP console hits US in March', 'Ask Jeeves joins web log market', 'Why Cell will get the hard sell', 'PlayStation 3 processor unveiled', 'Consumer concern over RFID tags', "Mobiles 'not media players yet'", "Blind student 'hears in colour'", 'Apple attacked over sources row', 'Mobile audio enters new dimension', 'DVD copy protection strengthened', 'Millions buy MP3 players in US', 'Britons fed up with net ser
# ...
